# %% [markdown]
# # Algorithms
#
# An **algorithm** is a sequence of instructions designed to perform a specific task. Understanding algorithms is crucial for problem-solving in computer science.
#
# Source/s:
# - Grokking Algorithms by Aditya Bhargava

# %% [markdown]
# ## Running Time
#
# When choosing an algorithm, efficiency is key. You generally want to optimize for either:
#
# - **Time**: How quickly the algorithm executes.
# - **Space**: How much memory it uses.
#
# For example, in the worst-case scenario of a **simple/linear/stupid search**, you might need to check every item in a list. This is known as **linear time**, where the maximum number of guesses is directly proportional to the size of the list.

# %% [markdown]
# ## Big O Notation
# Different algorithms don't grow at the same rate. It is not enough to know that an algorithm is O(n^2). You need to know how the running time grows as the input size increases. This is where Big O notation comes in.
#
# To analyze the efficiency of an algorithm, we use **Big O notation**. This mathematical notation helps describe how the running time or space requirements of an algorithm grow as the input size increases.
#
# &Omicron;(n)
# - Here, $n$ represents the size of the input.
# - This notation is used to describe linear time, where the running time increases linearly with the size of the input.
#
# Example:
# You need to create 16 squares in a grid.
#
# **Algorithm 1**:
# - You can create the squares one by one.
#
# **Algorithm 2**:
# - You can create the squares by folding a paper in half and then folding it in half again. Similarly, you can create 16 squares in 4 folds.
#
# > Note that Big O establishes an **upper bound** on the running time of an algorithm. It describes the **worst-case scenario**.
# > Hence linear time is a reassurance that the algorithm will NEVER BE SLOWER than $O(n)$.
#
# *It is also important to look at AVERAGE CASE scenarios.*
#
# ## Common Big O Runtimes
# * $O(log n)$ - logarithmic time
# Example: Binary search
#
# * $O(n)$ - linear time
# Example: Simple search
#
# * $O(n * log n)$ - linearithmic time
# Example: Quicksort - a fast sorting algorithm
#
# * $O(n^2)$ - quadratic time
# Example: Selection sort - a slow sorting algorithm
#
# * $O(n!)$ - factorial time
# Example: Traveling salesperson problem
#
# ### Example: Folding Paper to get 16 Squares
# - **Algorithm 1**: $O(n)$
# We need to create 16 squares one by one. This is a linear time algorithm.
#
# - **Algorithm 2**: $O(log n)$
# We can create 16 squares by folding a paper in half and then folding it in half again. This is a logarithmic time algorithm.
#
# ![image.png](attachment:image.png)

# %%
# Curious how to plot Big O Notation graphs hehehe
# Plotting Big O Notation Graphs

import numpy as np
import matplotlib.pyplot as plt

# Define input size
n = np.arange(1, 100000)

# Define different Big O functions
O_1 = np.ones_like(n)  # O(1)
O_log_n = np.log(n)    # O(log n)
O_n = n                 # O(n)
O_n_log_n = n * np.log(n)  # O(n log n)
O_n_squared = n**2     # O(n^2)

# Create the plot
plt.figure(figsize=(10, 6))

plt.plot(n, O_1, label='O(1)', color='blue')
plt.plot(n, O_log_n, label='O(log n)', color='orange')
plt.plot(n, O_n, label='O(n)', color='green')
plt.plot(n, O_n_log_n, label='O(n log n)', color='red')
plt.plot(n, O_n_squared, label='O(n^2)', color='purple')

# Adding labels and title
plt.ylim(0, 10000)  # Limit y-axis for better visibility
plt.xlim(1, 1000)   # Limit x-axis
plt.title('Big O Notation Graphs')
plt.xlabel('Input Size (n)')
plt.ylabel('Operations')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Importance of Trade-offs
#
# It's essential to understand the trade-offs between different algorithms and data structures. For instance:
#
# - Should you use **merge sort** or **quicksort** for sorting data?
# - Is it better to use an **array** or a **list** for your data storage?
#
# Choosing the right algorithm or data structure can greatly affect performance.

# %% [markdown]
# ## Traveling Salesperson Problem
# In this problem
# - You have a salesperson.
# - This salesperson needs to visit a list of cities.
# - They can only visit each city once.
# - They want to take the shortest possible route.
#
# ### Calculating the Number of Routes/Operations
# To find the shortest route, you need to evaluate every possible order in which the salesperson can visit the cities. Each unique order represents a different permutation of the cities.
#
# Now solving the operations in the following order:
#
# $n! = n * (n-1) * (n-2) * ... * 1$
#
# > At first we have n cities to choose from, then after choosing one city, we have n-1 cities to choose from, and so on.
#
#
# Note that the number of operations grows very quickly as the number of cities increases.
# - 3 cities has 6 operations
# $3! = 3 * 2 * 1 = 6$
# - 5 cities has 120 operations
# $5! = 5 * 4 * 3 * 2 * 1 = 120$
# - 6 cities has 720 operations
# $6! = 6 * 5 * 4 * 3 * 2 * 1 = 720$
#
# This is an algorithm with a really bad runtime of $O(n!)$. This means that the running time grows factorially with the size of the input.

# %% [markdown]
# ## Types of Algorithms

# %% [markdown]
# ### Sorting Algorithms
#
# Sorting algorithms are methods used to arrange data in a specific order (e.g., ascending or descending). They are fundamental in organizing data efficiently.
#
# *Next steps*: Explore various sorting algorithms to understand their strengths and weaknesses.

# %% [markdown]
# #### Selection Sort

# %% [markdown]
# ### Searching Algorithms
#
# Searching algorithms help locate specific data within a structure.

# %% [markdown]
# #### Binary Search
#
# Binary search is an efficient algorithm for finding a target value in a **sorted array**. By repeatedly dividing the search interval in half, binary search can significantly reduce the number of comparisons needed compared to linear search methods.
#
# See the [Binary Search](<Search Algorithm/BinarySearch.ipynb>) notebook for an in-depth explanation.

# %% [markdown]
# # Key Takeaways
#
# - **Binary Search vs. Simple Search**: Binary search is much faster than a simple search.
# - **Efficiency Comparison**: $O(log n)$ is more efficient than $O(n)$, especially as the size of the list increases.
# - **Measuring Speed**: The speed of an algorithm isn’t measured in seconds; it’s about how it grows with larger inputs.
# - **Growth Notation**: We use *Big O notation* to describe the time complexity of algorithms.
