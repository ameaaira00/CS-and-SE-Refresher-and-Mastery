# %% [markdown]
# # Algorithms
#
# An **algorithm** is a sequence of instructions designed to perform a specific task. Understanding algorithms is crucial for problem-solving in computer science.
#
# Source/s:
# - Grokking Algorithms by Aditya Bhargava

# %% [markdown]
# ## Running Time
#
# When choosing an algorithm, efficiency is key. You generally want to optimize for either:
#
# - **Time**: How quickly the algorithm executes.
# - **Space**: How much memory it uses.
#
# For example, in the worst-case scenario of a **simple/linear/stupid search**, you might need to check every item in a list. This is known as **linear time**, where the maximum number of guesses is directly proportional to the size of the list.

# %% [markdown]
# ## Big O Notation
# Different algorithms don't grow at the same rate. It is not enough to know that an algorithm is O(n^2). You need to know how the running time grows as the input size increases. This is where Big O notation comes in.
#
# To analyze the efficiency of an algorithm, we use **Big O notation**. This mathematical notation helps describe how the running time or space requirements of an algorithm grow as the input size increases.
#
# &Omicron;(n)
# - Here, $n$ represents the size of the input.
# - This notation is used to describe linear time, where the running time increases linearly with the size of the input.
#
# Example:
# You need to create 16 squares in a grid.
#
# **Algorithm 1**:
# - You can create the squares one by one.
#
# **Algorithm 2**:
# - You can create the squares by folding a paper in half and then folding it in half again. Similarly, you can create 16 squares in 4 folds.
#
# > Note that Big O establishes an **upper bound** on the running time of an algorithm. It describes the **worst-case scenario**.
# > Hence linear time is a reassurance that the algorithm will NEVER BE SLOWER than $O(n)$.
#
# *It is also important to look at AVERAGE CASE scenarios.*
#
# ## Common Big O Runtimes
# * $O(log n)$ - logarithmic time
# Example: Binary search
#
# * $O(n)$ - linear time
# Example: Simple search
#
# * $O(n * log n)$ - linearithmic time
# Example: Quicksort - a fast sorting algorithm
#
# * $O(n^2)$ - quadratic time
# Example: Selection sort - a slow sorting algorithm
#
# * $O(n!)$ - factorial time
# Example: Traveling salesperson problem
#
# ### Example: Folding Paper to get 16 Squares
# - **Algorithm 1**: $O(n)$
# We need to create 16 squares one by one. This is a linear time algorithm.
#
# - **Algorithm 2**: $O(log n)$
# We can create 16 squares by folding a paper in half and then folding it in half again. This is a logarithmic time algorithm.

# %% [markdown]
# ### Big O Notation Graphs

# %%
# Curious how to plot Big O Notation graphs using np hehehe
# Plotting Big O Notation Graphs

import numpy as np
import matplotlib.pyplot as plt

# Define input size
n = np.arange(1, 1000)

# Define different Big O functions
functions = {
    'O(1)': np.ones_like(n),
    'O(log n)': np.log(n),
    'O(n)': n,
    'O(n log n)': n * np.log(n),
    'O(n^2)': n**2
}

# Plot each function individually
for label, values in functions.items():
    plt.figure(figsize=(10, 6))
    plt.plot(n, values, label=label)
    plt.ylim(0, 10000)  # Limit y-axis for better visibility
    plt.xlim(1, 1000)   # Limit x-axis
    plt.title(f'Graph of {label}')
    plt.xlabel('Input Size (n)')
    plt.ylabel('Operations')
    plt.legend()
    plt.grid()
    plt.show()

# %%
# Define input size
n = np.arange(1, 100000)

# Define different Big O functions
O_1 = np.ones_like(n)  # O(1)
O_log_n = np.log(n)    # O(log n)
O_n = n                 # O(n)
O_n_log_n = n * np.log(n)  # O(n log n)
O_n_squared = n**2     # O(n^2)

# Create the plot
plt.figure(figsize=(10, 6))

plt.plot(n, O_1, label='O(1)', color='blue')
plt.plot(n, O_log_n, label='O(log n)', color='orange')
plt.plot(n, O_n, label='O(n)', color='green')
plt.plot(n, O_n_log_n, label='O(n log n)', color='red')
plt.plot(n, O_n_squared, label='O(n^2)', color='purple')

# Adding labels and title
plt.ylim(0, 10000)  # Limit y-axis for better visibility
plt.xlim(1, 1000)   # Limit x-axis
plt.title('Big O Notation Graphs')
plt.xlabel('Input Size (n)')
plt.ylabel('Operations')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Importance of Trade-offs
#
# It's essential to understand the trade-offs between different algorithms and data structures. For instance:
#
# - Should you use **merge sort** or **quicksort** for sorting data?
# - Is it better to use an **array** or a **list** for your data storage?
#
# Choosing the right algorithm or data structure can greatly affect performance.

# %% [markdown]
# ## Traveling Salesperson Problem
# In this problem
# - You have a salesperson.
# - This salesperson needs to visit a list of cities.
# - They can only visit each city once.
# - They want to take the shortest possible route.
#
# ### Calculating the Number of Routes/Operations
# To find the shortest route, you need to evaluate every possible order in which the salesperson can visit the cities. Each unique order represents a different permutation of the cities.
#
# Now solving the operations in the following order:
#
# $n! = n * (n-1) * (n-2) * ... * 1$
#
# > At first we have n cities to choose from, then after choosing one city, we have n-1 cities to choose from, and so on.
#
#
# Note that the number of operations grows very quickly as the number of cities increases.
# - 3 cities has 6 operations
# $3! = 3 * 2 * 1 = 6$
# - 5 cities has 120 operations
# $5! = 5 * 4 * 3 * 2 * 1 = 120$
# - 6 cities has 720 operations
# $6! = 6 * 5 * 4 * 3 * 2 * 1 = 720$
#
# This is an algorithm with a really bad runtime of $O(n!)$. This means that the running time grows factorially with the size of the input.

# %% [markdown]
# # Types of Algorithms

# %% [markdown]
# ## Sorting Algorithms 🩳
#
# Sorting algorithms are methods used to arrange data in a specific order (e.g., ascending or descending). They are fundamental in organizing data efficiently.
#
# *Next steps*: Explore various sorting algorithms to understand their strengths and weaknesses.

# %% [markdown]
# ### Selection Sort 🫵
#
# Selection sort is a simple sorting algorithm that works by selecting the smallest (or largest) element from the unsorted portion of the list and moving it to the sorted portion.
#
# - **Time Complexity**: $O(n^2)$
# - **Space Complexity**: $O(1)$
#
# See the [Selection Sort](<Sorting Algorithms/SelectionSort.ipynb>) notebook for a detailed explanation.

# %% [markdown]
# ## Searching Algorithms 🔍
#
# Searching algorithms help locate specific data within a structure.

# %% [markdown]
# ### Binary Search 💔
#
# Binary search is an efficient algorithm for finding a target value in a **sorted array**. By repeatedly dividing the search interval in half, binary search can significantly reduce the number of comparisons needed compared to linear search methods.
#
# - **Time Complexity**: $O(log n)$
# - **Space Complexity**: $O(1)$
#
# See the [Binary Search](<Search Algorithm/BinarySearch.ipynb>) notebook for an in-depth explanation.

# %% [markdown]
# ## Section Key Takeaways
#
# - **Binary Search vs. Simple Search**: Binary search is much faster than a simple search.
# - **Efficiency Comparison**: $O(log n)$ is more efficient than $O(n)$, especially as the size of the list increases.
# - **Measuring Speed**: The speed of an algorithm isn’t measured in seconds; it’s about how it grows with larger inputs.
# - **Growth Notation**: We use *Big O notation* to describe the time complexity of algorithms.

# %% [markdown]
# # Recursion
#
# - A coding technique used in many algorithms.
# - A function that calls itself.
#
# > **Pseudocode**: A way to describe algorithms that uses a mixture of code and plain English, closer to human language.
#
# Now back to recursion... let's explore the difference between **while loops** and **recursion**.
# - While loops are iterative which means they use a loop to repeat until a condition is met.
# - Recursion is when a function calls itself, which means it repeats until a base case is reached.
# Both approaches can be used to solve the same problem, but some argue that recursion is more elegant.
#
# However, recursion can be less efficient than iteration. This is because each time a function calls itself, the computer must allocate memory for each function call. This can lead to a stack overflow if the recursion goes too deep.
#
# Some prefer recursion because it can make code shorter and easier to read.
#
# ## Base and Recursive Cases
# A recursive function calls itself so ending up in an infinite loop is a common concern. To avoid this, you need to define a **base case**. This is the condition that stops the recursion.
#
# Recursion is made up of two cases:
# - **Base case**: The condition that stops the recursion.
# - **Recursive case**: The condition that continues the recursion.

# %%
# Count down using recursion
def count_down(n):
    if n <= 0:
        return
    print(n)
    count_down(n - 1)

count_down(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
# Count down using a for loop
for i in range(5, 0, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
# Count down using a while loop
i = 5
while i > 0:
    print(i)
    i -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# ### The stack
# A call stack is a data structure that stores information about the active subroutines of a computer program. This is important because recursion uses the call stack to keep track of function calls.
#
# When a function calls itself, the computer must remember the state of the original function. This is where the call stack comes in. It stores the state of each function call.
#
# This has 2 actions: Push and Pop
# - **Push**: Add a new function to the stack.
# - **Pop**: Remove the top function from the stack.
# This data structure is called a stack.
#
# #### Call Stack in Recursion
# When a function calls itself, the computer must remember the state of the original function. This is where the call stack comes in. It stores the state of each function call.
#
# Let's walk through what happens when we call a function:
#
# ```
# def greet(name):
#     print("hello, " + name + "!")
#     greet2(name)
#     print("getting ready to say bye...")
#     bye()
# ```
# Suppose we call `greet("Selene")`.
# 1. First, the computer allocates memory for the function call.
# |==|
# 2. Then, it pushes the function onto the call stack.
# |greet|
# 3. The function executes.
# 4. The computer then calls `greet2(name)`.
# |greet2|
# |greet|
# 5. After `greet2` finishes, the computer pops `greet2` off the stack.
# |greet|
# 6. The computer then calls `bye()`.
# |bye|
# |greet|
# 7. After `bye` finishes, the computer pops `bye` off the stack.
# |greet|
# 8. Finally, the computer pops `greet` off the stack. When there's nothing left on the stack, the program is done.
#
# This is called the **call stack**. It's a stack data structure that stores information about the active subroutines of a computer program.

# %% [markdown]
# Now let's use factorial as an example to understand recursion and call stack better.
#
# Factorial is the product of an integer and all the integers below it. For example, the factorial of 5 is $5 * 4 * 3 * 2 * 1 = 120$

# %%
# Factorial using recursion
def factorial(n):
    print(f'Calculating factorial of {n}...')
    if n == 0: # The base case is when we reach 0
        print(f'Factorial of {n} is 1')
        return 1 
    print(f'Factorial of {n} is {n} * factorial({n - 1})')
    return n * factorial(n - 1) # The recursive case is when n > 0

print(factorial(3)) # 3 * 2 * 1 = 6
# Out:
# Calculating factorial of 3...
# Factorial of 3 is 3 * factorial(2)
# Calculating factorial of 2...
# Factorial of 2 is 2 * factorial(1)
# Calculating factorial of 1...
# Factorial of 1 is 1 * factorial(0)
# Calculating factorial of 0...
# Factorial of 0 is 1
# 6

# %% [markdown]
# Now let's understand how the call stack works with recursion by calculating the factorial of 3.
#
# When we call `factorial(3)`, the call stack looks like this:
# 1. `factorial(3)` is pushed onto the stack.
# |factorial(3)|
# 2. `factorial(2)` is pushed onto the stack.
# |factorial(2)|
# |factorial(3)|
# 3. `factorial(1)` is pushed onto the stack.
# |factorial(1)|
# |factorial(2)|
# |factorial(3)|
# 4. Since `factorial(1)` is the base case where `n = 1`, it returns 1 to `factorial(2)`. We haven't finished a call until now.
# |factorial(2)|
# |factorial(3)|
# 5. `factorial(2)` returns `2 * 1 = 2` to `factorial(3)`.
# |factorial(3)|
# 6. `factorial(3)` returns `3 * 2 = 6`.
#
# Note that each call has its own copy of `n`, and we can't access the `n` of another call. The call stack stores the state of each function call.
#
# #### Cost of Recursion
# Saving those info can be costly. What we can do is
# a. Use a loop instead of recursion.
# b. Use tail recursion.
#
# #### Tail Recursion
# This is a special form of recursion where the recursive call is the last thing the function does. This is important because it allows the computer to optimize the recursion by reusing the stack frame for the next call.
#
# An example of tail recursion is the factorial function. Here's how it looks:

# %%
# Tail recursion sample
def factorial_tail(n, accumulator=1):
    print(f'Calculating factorial of {n}...')
    if n == 0: # The base case is when we reach 0
        print(f'Factorial of {n} is {accumulator}')
        return accumulator
    print(f'Factorial of {n} is factorial({n - 1}, {n} * {accumulator})')
    return factorial_tail(n - 1, n * accumulator) # The recursive case is when n > 0

print(factorial_tail(3)) # 3 * 2 * 1 = 6
# Out:
# Calculating factorial of 3...
# Factorial of 3 is factorial(2, 3 * 1)
# Calculating factorial of 2...
# Factorial of 2 is factorial(1, 2 * 3)
# Calculating factorial of 1...
# Factorial of 1 is factorial(0, 1 * 6)
# Calculating factorial of 0...
# Factorial of 0 is 6
# 6

# %% [markdown]
# Here, the recursive call is the last thing the function does. This allows the computer to optimize the recursion by reusing the stack frame for the next call.
#
# The call stack for tail recursion looks like this:
# 1. `factorial(3, 1)` is pushed onto the stack.
# |factorial(3, 1)|
# 2. `factorial(2, 3)` is pushed onto the stack.
# |factorial(2, 3)|
# 3. `factorial(1, 6)` is pushed onto the stack.
# |factorial(1, 6)|
# 4. Since `n = 1`, `factorial(1, 6)` returns 6 to `factorial(2, 3)`.
# |factorial(2, 3)|
# 5. `factorial(2, 3)` returns 6 to `factorial(3, 1)`.
# |factorial(3, 1)|
# 6. `factorial(3, 1)` returns 6.

# %% [markdown]
# ### Section Key Takeaways
# - Recursion is when a function calls itself.
# - It has two cases: the base case and the recursive case.
# - A stack has two actions: push and pop.
# - Function calls are stored in a call stack.
# - Call stacks store the state of each function call. But this can be costly.

# %% [markdown]
# ## Quicksort
# - A fast sorting algorithm.
# - Uses divide and conquer to sort a list.
#
# ### Divide and Conquer
# This is a technique of breaking a problem into smaller pieces, solving the smaller pieces, and then combining those solutions to solve the original problem.
#
# To put D&C simply:
# 1. **Divide**: Break the problem into smaller subproblems that are similar to the original problem.
# 2. **Conquer**: Solve the subproblems.
# 3. **Combine**: Combine the solutions to solve the original problem.
#
# #### Real-World Example
# Suppose you have a plot of land and you need to divide it evenly into square plots. You can use D&C to solve this problem:
# 1. Figure out the base case.
# 2. Divide the land until you reach the base case.
#
# Suppose you have 1680 x 640 meters of land.
# 1. Figure out the base
# - The base case is when the land is a square plot. So each side is the same length.
# 2. Divide the land
# - Recall that the land is 1680 x 640 meters.
# - Get the biggest square plot that fits into the land.
# ex. We get 2 square plots of 640 x 640 meters. Which leaves us with (1680-2*640) = 400 x 640 meters.
# - Left 400 x 640 meters of land.
# We can get 1 square plot of 400 x 400 meters. Which leaves us with (640-400) = 240 x 400 meters.
# - Left 240 x 400 meters of land.
# We can get 1 square plot of 240 x 240 meters. Which leaves us with (400-240) = 160 x 240 meters.
# - Left 160 x 240 meters of land.
# We can get 1 square plot of 160 x 160 meters. Which leaves us with (240-160) = 80 x 160 meters.
# - Left 80 x 160 meters of land.
# We can get 2 even square plots of 80 x 80 meters. We have reached the base case!
#
# Hence, the biggest plot size is 80 x 80 meters.
#
# #### Euclid's Algorithm
# Euclid's algorithm is a classic example of D&C. It finds the greatest common divisor of two numbers.
#
# Here's how it works for 48 and 18:
# 1. **Divide**: Divide the larger number by the smaller number.
# 48 divided by 18 is 2 with a remainder of 12.
# 2. **Conquer**: Repeat the process with the smaller number and the remainder.
# 18 divided by 12 is 1 with a remainder of 6.
# 3. **Combine**: Repeat the process until the remainder is 0.
# 12 divided by 6 is 2 with a remainder of 0.
#
# Thus, the greatest common divisor of 48 and 18 is 6.

# %%
# Let's take summation as an example

# Summation using for loop
def sum(arr):
    total = 0
    for num in arr:
        total += num
    return total

print(sum([1, 2, 3, 4, 5])) # 15
# Out:
# 15

# %%
# Summation using recursion
def sum_recursive(arr):
    if len(arr) == 0:
        return 0
    return arr[0] + sum_recursive(arr[1:])

print(sum_recursive([1, 2, 3])) # 6
# Out:
# 6

# %% [markdown]
# The call stack for `sum_recursive([1, 2, 3])` looks like this:
# 1. `sum_recursive([1, 2, 3])` is pushed onto the stack.
# |sum_recursive([1, 2, 3])|
# 2. `sum_recursive([2, 3])` is pushed onto the stack.
# |sum_recursive([2, 3])|
# |sum_recursive([1, 2, 3])|
# 3. `sum_recursive([3])` is pushed onto the stack.
# |sum_recursive([3])|
# |sum_recursive([2, 3])|
# |sum_recursive([1, 2, 3])|
# 4. `sum_recursive([])` is pushed onto the stack.
# |sum_recursive([])|
# |sum_recursive([3])|
# |sum_recursive([2, 3])|
# |sum_recursive([1, 2, 3])|
# 5. Since `arr` is empty, `sum_recursive([])` returns 0 to `sum_recursive([3])` which is then added to `arr[0]`. Here arr[0] is 3.
# |sum_recursive([3])|
# |sum_recursive([2, 3])|
# |sum_recursive([1, 2, 3])|
# 6. `sum_recursive([3])` returns 3 to `sum_recursive([2, 3])` which is then added to `arr[0]`. Here arr[0] is 2.
# |sum_recursive([2, 3])|
# |sum_recursive([1, 2, 3])|
# 7. `sum_recursive([2, 3])` returns 5 to `sum_recursive([1, 2, 3])` which is then added to `arr[0]`. Here arr[0] is 1.
# |sum_recursive([1, 2, 3])|
# 8. `sum_recursive([1, 2, 3])` returns 6 to the caller.

# %% [markdown]
# #### Why not alwasy use Loop instead of Recursion?
# Sneaking peak to Functional Programming:
# - Recursion is a key concept in functional programming.
# - Functional programming languages don't have loops.
# - Instead, they use recursion to iterate.

# %% [markdown]
# #### Now back to Quicksort...
#
# Quicksort is a sorting algorithm that uses D&C to sort a list. Here's how it works in sorting a list of numbers:
#
# 1. Figure out the base case.
# - No need to sort a list of 0 or 1 element.

# %%
def quicksort(arr):
    print(f'Sorting {arr}...')
    if len(arr) < 2:
        return arr
    pivot = arr[0]
    print(f'Pivot is {pivot} for {arr}')
    less = [i for i in arr[1:] if i <= pivot]
    greater = [i for i in arr[1:] if i > pivot]
    return quicksort(less) + [pivot] + quicksort(greater)

print(quicksort([10, 5, 2, 3])) # [2, 3, 5, 10]
# Out:
# Sorting [10, 5, 2, 3]...
# Pivot is 10 for [10, 5, 2, 3]
# Sorting [5, 2, 3]...
# Pivot is 5 for [5, 2, 3]
# Sorting [2, 3]...
# Pivot is 2 for [2, 3]
# Sorting []...
# Sorting [3]...
# Sorting []...
# Sorting []...
# [2, 3, 5, 10]

# %% [markdown]
# Looking into arrays with more than 1 element:
# `[5, 3, 7, 2, 8, 4, 1]`
#
# 2. Pick a pivot point. The best pivot point is the median as it divides the list into two equal halves.
# - Pivot point is the value around which the list is divided.
# ex. We can pick 5 as the pivot point.
#
# 3. Partition the list into two sublists: elements less than the pivot and elements greater than the pivot.
# `[3, 2, 4, 1]` `5` `[7, 8]`
# - This is called the partitioning step. Our **Divide** step.
# - Now we have
#     1. A list of elements less than 5.
#     2. The pivot point 5.
#     3. A list of elements greater than 5.
#
# 4. Recursively apply quicksort to the sublists. (Choose a new pivot point and partition the list.)
# `[3, 2, 4, 1]` 5 `[7, 8]`
# - We can choose 3 and 7 as the pivot point.
# - `[2, 1]` 3 `[4]` 5 `[]` 7 `[8]` # Here, we've reached some base cases.
# - We can choose 2 and 4 as the pivot point.
# - `[1]` 2 `[]` 3 4 5 7 8
# - 1 2 3 4 5 7 8
#
# Now we have a sorted list!
#
# #### Quicksort in Action
# Let's see how quicksort works on the list `[5, 3, 7, 2, 8, 4, 1]` -> choose 5 as the pivot point.
# - `[3, 2, 4, 1]` 5 `[7, 8]` -> choose 3 and 7 as the pivot point.
# - `[2, 1]` 3 `[4]` 5 `[]` 7 `[8]` -> choose 2 and 4 as the pivot point.
# - `[1]` 2 `[]` 3 4 5 7 8
# - 1 2 3 4 5 7 8
#
#
# #### Inductive Proof
# - A way to prove that an algorithm works.
# - It involves proving that the algorithm works for a base case and then proving that it works for an arbitrary case.
#
# 1. **Base case**: The algorithm works for a list of 0 or 1 element.
# 2. **Inductive step**: Assume that the algorithm works for a list of `n` elements. Prove that it works for a list of `n + 1` elements.
#
#
# ### Let's explore the Quicksort algorithm in more detail.

# %%
def quicksort(array):
    if len(array) < 2: # Base case: arrays with 0 or 1 element are already sorted
        return array
    else: # Recursive case 
        pivot = array[0]
        # Sub-array of all the elements less than the pivot
        less = [i for i in array[1:] if i <= pivot]

        # Sub-array of all the elements greater than the pivot
        greater = [i for i in array[1:] if i > pivot]
        
        return quicksort(less) + [pivot] + quicksort(greater)

# %% [markdown]
# #### Big O Notation
# The speed of Quicksort depends on the pivot point.
# - If the pivot point is the smallest or largest element, the runtime is $O(n^2)$. This is the worst-case scenario. As slow as Selection Sort!
# - If the pivot point is the middle element, the runtime is $O(n * log n)$. As fast as Merge Sort!
#
# Why not Merge Sort?
# - TLDNR: Merge Sort uses more space than Quicksort.
#
# ### Quicksort vs. Merge Sort
# - Merge Sort is a sorting algorithm that uses D&C to sort a list.
# - It divides the list into two halves, sorts each half, and then merges the sorted halves together.
# - Merge Sort is slower than Quicksort because it uses more space.
# - Quicksort is usually faster than Merge Sort because it has smaller constant factors.
#
# #### Constant Factors???
# - Note that when we write O(n) notation, this really means `c * n` where `c` is some fixed amount of time the algorithm takes to run.
# - Constant are usually ignored in Big O notation. This is because they don't matter when we're talking about the growth of an algorithm.
# - But there are cases where constants do matter. For example, if you have a small dataset, a $O(n^2)$ algorithm might be faster than a $O(n * log n)$ algorithm because the constant factors are smaller.
# - Quick sort is usually faster than Merge Sort because it has smaller constant factors. This is because it uses less space than Merge Sort.
#
# Recall that in choosing a pivot point, the best pivot point is the median.
# - This will divide the list into two equal halves. Which gives us `O(log n)` levels of recursion.
# `O(n)` time x `O(log n)` levels = `O(n * log n)` time.
# - Choosing the smallest or largest element as the pivot point will give us `O(n)` levels of recursion. This is the worst-case scenario.
# `O(n)` time x `O(n)` levels = `O(n^2)` time.
#
# The best case is also the average case for Quicksort. If we choose a random element as the pivot point, the runtime is `O(n * log n)`.

# %%
# Merge sort
def merge_sort(arr):
    print(f'Sorting {arr}...')
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return left + right 

print(merge_sort([10, 5, 2, 3])) # [[10], [5], [2], [3]]
# Out:
# Sorting [10, 5, 2, 3]...
# Sorting [10, 5]...
# Sorting [10]...
# Sorting [5]...
# Sorting [2, 3]...
# Sorting [2]...
# Sorting [3]...
# [10, 5, 2, 3]

# %% [markdown]
# ### Section Key Takeaways
# - **Divide and Conquer**: A technique that breaks a problem into smaller and smaller pieces.
# - **Quicksort**: A fast sorting algorithm that uses D&C to sort a list.
# - Choose a random element as the pivot point to get the average case runtime of `O(n * log n)`.
# - **Base Case**: The condition that stops the recursion.
# - **Inductive Proof**: A way to prove that an algorithm works.
# - **Constant Factors**: Usually ignored in Big O notation, but they can matter in some cases.
